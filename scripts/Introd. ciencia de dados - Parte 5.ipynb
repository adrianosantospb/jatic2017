# %% [markdown]
# # Análise de correlação
# ### Por Adriano Santos
#
# ###### Definição
#
# Em teoria da probabilidade e estatística, correlação, também chamada de coeficiente de correlação, indica a força e a direção do relacionamento linear entre duas variáveis aleatórias, embora não implique causalidade.
#
# ###### Interpretação
#
# * 0.9 para mais ou para menos indica uma correlação muito forte.
# * 0.7 a 0.9 positivo ou negativo indica uma correlação forte.
# * 0.5 a 0.7 positivo ou negativo indica uma correlação moderada.
# * 0.3 a 0.5 positivo ou negativo indica uma correlação fraca.
# * 0 a 0.3 positivo ou negativo indica uma correlação desprezível.

# %%
# Importando os módulos que serão utilizados
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importando os dados
df = pd.read_csv('../Dados/USDA.csv', delimiter=',')

# %%
# Calculando as correlações
df.corr()
# Out:
#                     ID  Calories   Protein  TotalFat  Carbohydrate    Sodium  \
# ID            1.000000  0.052325  0.096839 -0.061211      0.121758 -0.034822
# Calories      0.052325  1.000000  0.135258  0.807770      0.434701  0.033703
# Protein       0.096839  0.135258  1.000000  0.061682     -0.284500 -0.003253
# TotalFat     -0.061211  0.807770  0.061682  1.000000     -0.109399  0.003390
# Carbohydrate  0.121758  0.434701 -0.284500 -0.109399      1.000000  0.049544
# Sodium       -0.034822  0.033703 -0.003253  0.003390      0.049544  1.000000
# SaturatedFat -0.069872  0.611601  0.045784  0.766142     -0.108676 -0.005075
# Cholesterol  -0.030098  0.032433  0.280578  0.097111     -0.216070 -0.018348
# Sugar         0.074157  0.309989 -0.289221 -0.055459      0.688422 -0.007078
# Calcium      -0.036164  0.112560  0.041071  0.006585      0.187122  0.174784
# Iron         -0.047206  0.192506  0.133609 -0.051781      0.362023  0.027904
# ...

# %%
# Perceba que existe uma correlação positiva forte entre Calories e TotalFat (0.807770)
# %matplotlib inline
ax = plt.scatter (df['Calories'], df['TotalFat'])
